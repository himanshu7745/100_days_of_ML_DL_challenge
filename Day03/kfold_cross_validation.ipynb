# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Load Dataset
housing = fetch_california_housing()

X = housing.data
y = housing.target

model = LinearRegression()

# %%
# 5 Fold CV
kf5 = KFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scores5 = cross_val_score(
    model,
    X,
    y,
    cv=kf5,
    scoring="neg_mean_squared_error"
)

mse5 = -scores5.mean()

# %%
# 10 Fold CV
kf10 = KFold(
    n_splits=10,
    shuffle=True,
    random_state=42
)

scores10 = cross_val_score(
    model,
    X,
    y,
    cv=kf10,
    scoring="neg_mean_squared_error"
)

mse10 = -scores10.mean()

# %%
print("Cross Validation Results")
print("-" * 40)
print("5 Fold MSE :", mse5)
print("10 Fold MSE:", mse10)

# Comparison Plot
plt.figure(figsize=(8,6))
plt.bar(
    ["5-Fold CV", "10-Fold CV"],
    [mse5, mse10]
)

plt.ylabel("Mean Squared Error")
plt.title("5-Fold vs 10-Fold Cross Validation")
plt.show()
# Out:
# Cross Validation Results
# ----------------------------------------
# 5 Fold MSE : 0.5305724639238878
# 10 Fold MSE: 0.5325266619260589
